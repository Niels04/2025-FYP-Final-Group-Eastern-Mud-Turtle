# %%
from img_util import rate_hair
import pandas as pd
import os
import cv2
import numpy as np
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# set up directories and files
folder_path = "../data/hair_annotations"
ah = pd.read_csv("../data/annotations.csv")

# get information from the train set
train_set = ah[ah['Group_ID'] != 'C']
true_labels = train_set['Rating_Final']

# initialize variables to store best results
best_acc = 0
best_acc_blur = 0
best_param, best_param_blur = None, None
best_t1, best_t2 = None, None
best_t1_blur, best_t2_blur = None, None

# store all results
results = []  

# iterate over parameter values
for p in range(110, 255, 5):

    # iterate through possible threshold values
    for t1 in np.linspace(0.01, 0.5, 49):
        s = max(t1 + 0.01, 0.09)
        for t2 in np.linspace(s, 1.0, 100 - int(s * 100)):
            
            # list to store predictions (no blur and blur)
            pred_labels = []
            pred_labels_blur = []

            # predict labels
            for i, row in train_set.iterrows():

                # load image
                filename = row['FileID'] + '.png'
                img_path = os.path.join(folder_path, filename)
                img = cv2.imread(img_path)
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

                # compute label with and without blur
                _, label, _ = rate_hair(img_rgb, t1= t1, t2= t2, dst= p, blur= False)
                _, label_blur, _ = rate_hair(img_rgb, t1= t1, t2= t2, dst= p)
                pred_labels.append(label)
                pred_labels_blur.append(label_blur)
            
            # compute accuracy, save it if best result yet
            acc = accuracy_score(true_labels, pred_labels)
            acc_blur = accuracy_score(true_labels, pred_labels_blur)

            if acc > best_acc:
                best_acc = acc
                best_param = p
                best_t1, best_t2 = t1, t2

            if acc_blur > best_acc_blur:
                best_acc_blur = acc_blur
                best_param_blur = p
                best_t1_blur, best_t2_blur = t1, t2
            
            # save data
            results.append({
                "t1": t1,
                "t2": t2,
                "dst": p,
                "acc": acc,
                "acc_blur": acc_blur
            })

            # status update
            print(f"Trying dst= {p}, t1= {t1:.2f}, t2= {t2:.2f} | acc= {acc:.3f}, acc_blur={acc_blur:.3f}")

df = pd.DataFrame(results)

# results
print(f"  NO BLUR | Best thresholds: t1 = {best_t1:.3f}, t2 = {best_t2:.3f}; Best parameter: dst = {best_param}; with accuracy = {best_acc:.4f}")
print(f"WITH BLUR | Best thresholds: t1 = {best_t1_blur:.3f}, t2 = {best_t2_blur:.3f}; Best parameter: dst = {best_param_blur}; with accuracy = {best_acc_blur:.4f}")

# plots

# filter for best parameter value
subset = df[df["dst"] == best_param]

# get 2D grid
pivot = subset.pivot(index="t1", columns="t2", values="acc")

# plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pivot, cmap="viridis", cbar_kws={'label': 'Accuracy'})
plt.title(f"Accuracy heatmap at dst = {best_param}")
plt.xlabel("Upper threshold (t2)")
plt.ylabel("Lower threshold (t1)")
plt.show()

# best accuracy per parameter value
best_per_dst = df.groupby("dst").agg({
    "acc": "max",
    "acc_blur": "max"
}).reset_index()

plt.plot(best_per_dst["dst"], best_per_dst["acc"], label="No Blur")
plt.plot(best_per_dst["dst"], best_per_dst["acc_blur"], label="With Blur")
plt.xlabel("Parameter value (dst)")
plt.ylabel("Best accuracy")
plt.title("Best Accuracy vs. Bright Pixel Cutoff")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Trying dst= 110, t1= 0.01, t2= 0.09 | acc= 0.618, acc_blur=0.709
# Trying dst= 110, t1= 0.01, t2= 0.10 | acc= 0.648, acc_blur=0.709
# Trying dst= 110, t1= 0.01, t2= 0.11 | acc= 0.648, acc_blur=0.714
# Trying dst= 110, t1= 0.01, t2= 0.12 | acc= 0.668, acc_blur=0.714
# Trying dst= 110, t1= 0.01, t2= 0.13 | acc= 0.668, acc_blur=0.698
# Trying dst= 110, t1= 0.01, t2= 0.14 | acc= 0.673, acc_blur=0.688
# Trying dst= 110, t1= 0.01, t2= 0.15 | acc= 0.678, acc_blur=0.683
# Trying dst= 110, t1= 0.01, t2= 0.16 | acc= 0.678, acc_blur=0.678
# Trying dst= 110, t1= 0.01, t2= 0.17 | acc= 0.663, acc_blur=0.673
# Trying dst= 110, t1= 0.01, t2= 0.18 | acc= 0.648, acc_blur=0.663
# Trying dst= 110, t1= 0.01, t2= 0.19 | acc= 0.648, acc_blur=0.658
# Trying dst= 110, t1= 0.01, t2= 0.20 | acc= 0.638, acc_blur=0.653
# Trying dst= 110, t1= 0.01, t2= 0.21 | acc= 0.648, acc_blur=0.648
# Trying dst= 110, t1= 0.01, t2= 0.22 | acc= 0.643, acc_blur=0.648
# Trying dst= 110, t1= 0.01, t2= 0.23 | acc= 0.633, acc_blur=0.648
# Trying dst= 110, t1= 0.01, t2= 0.24 | acc= 0.618, acc_blur=0.648
# Trying dst= 110, t1= 0.01, t2= 0.25 | acc= 0.618, acc_blur=0.643
# Trying dst= 110, t1= 0.01, t2= 0.26 | acc= 0.618, acc_blur=0.643
# Trying dst= 110, t1= 0.01, t2= 0.27 | acc= 0.613, acc_blur=0.643
# Trying dst= 110, t1= 0.01, t2= 0.28 | acc= 0.603, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.29 | acc= 0.598, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.30 | acc= 0.598, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.31 | acc= 0.593, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.32 | acc= 0.593, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.33 | acc= 0.588, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.34 | acc= 0.588, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.35 | acc= 0.578, acc_blur=0.638
# Trying dst= 110, t1= 0.01, t2= 0.36 | acc= 0.578, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.37 | acc= 0.578, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.38 | acc= 0.578, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.39 | acc= 0.573, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.40 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.41 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.42 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.43 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.44 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.45 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.46 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.47 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.48 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.49 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.50 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.51 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.52 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.53 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.54 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.56 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.57 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.58 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.59 | acc= 0.568, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.60 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.61 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.62 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.63 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.64 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.65 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.66 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.67 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.68 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.69 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.70 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.71 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.72 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.73 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.74 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.75 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.76 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.77 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.78 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.79 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.80 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.81 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.82 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.83 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.84 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.85 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.86 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.87 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.88 | acc= 0.563, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.89 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.90 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.91 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.92 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.93 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.94 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.95 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.96 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.97 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.98 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 0.99 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.01, t2= 1.00 | acc= 0.558, acc_blur=0.633
# Trying dst= 110, t1= 0.02, t2= 0.09 | acc= 0.628, acc_blur=0.638
# Trying dst= 110, t1= 0.02, t2= 0.10 | acc= 0.658, acc_blur=0.638
# Trying dst= 110, t1= 0.02, t2= 0.11 | acc= 0.658, acc_blur=0.643
# Trying dst= 110, t1= 0.02, t2= 0.12 | acc= 0.678, acc_blur=0.643
# Trying dst= 110, t1= 0.02, t2= 0.13 | acc= 0.678, acc_blur=0.628
# Trying dst= 110, t1= 0.02, t2= 0.14 | acc= 0.683, acc_blur=0.618
# Trying dst= 110, t1= 0.02, t2= 0.15 | acc= 0.688, acc_blur=0.613
# Trying dst= 110, t1= 0.02, t2= 0.16 | acc= 0.688, acc_blur=0.608
# Trying dst= 110, t1= 0.02, t2= 0.17 | acc= 0.673, acc_blur=0.603
# Trying dst= 110, t1= 0.02, t2= 0.18 | acc= 0.658, acc_blur=0.593
# Trying dst= 110, t1= 0.02, t2= 0.19 | acc= 0.658, acc_blur=0.588
# Trying dst= 110, t1= 0.02, t2= 0.20 | acc= 0.648, acc_blur=0.583
# Trying dst= 110, t1= 0.02, t2= 0.21 | acc= 0.658, acc_blur=0.578
# Trying dst= 110, t1= 0.02, t2= 0.22 | acc= 0.653, acc_blur=0.578
# Trying dst= 110, t1= 0.02, t2= 0.23 | acc= 0.643, acc_blur=0.578
# Trying dst= 110, t1= 0.02, t2= 0.24 | acc= 0.628, acc_blur=0.578
# Trying dst= 110, t1= 0.02, t2= 0.25 | acc= 0.628, acc_blur=0.573
# Trying dst= 110, t1= 0.02, t2= 0.26 | acc= 0.628, acc_blur=0.573
# Trying dst= 110, t1= 0.02, t2= 0.27 | acc= 0.623, acc_blur=0.573
# Trying dst= 110, t1= 0.02, t2= 0.28 | acc= 0.613, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.29 | acc= 0.608, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.30 | acc= 0.608, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.31 | acc= 0.603, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.32 | acc= 0.603, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.33 | acc= 0.598, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.34 | acc= 0.598, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.35 | acc= 0.588, acc_blur=0.568
# Trying dst= 110, t1= 0.02, t2= 0.36 | acc= 0.588, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.37 | acc= 0.588, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.38 | acc= 0.588, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.39 | acc= 0.583, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.40 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.41 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.42 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.43 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.44 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.45 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.46 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.47 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.48 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.49 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.50 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.51 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.52 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.53 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.54 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.56 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.57 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.58 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.59 | acc= 0.578, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.60 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.61 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.62 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.63 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.64 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.65 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.66 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.67 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.68 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.69 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.70 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.71 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.72 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.73 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.74 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.75 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.76 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.77 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.78 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.79 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.80 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.81 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.82 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.83 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.84 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.85 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.86 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.87 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.88 | acc= 0.573, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.89 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.90 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.91 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.92 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.93 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.94 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.95 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.96 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.97 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.98 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 0.99 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.02, t2= 1.00 | acc= 0.568, acc_blur=0.563
# Trying dst= 110, t1= 0.03, t2= 0.09 | acc= 0.608, acc_blur=0.618
# Trying dst= 110, t1= 0.03, t2= 0.10 | acc= 0.638, acc_blur=0.618
# Trying dst= 110, t1= 0.03, t2= 0.11 | acc= 0.638, acc_blur=0.623
# Trying dst= 110, t1= 0.03, t2= 0.12 | acc= 0.658, acc_blur=0.623
# Trying dst= 110, t1= 0.03, t2= 0.13 | acc= 0.658, acc_blur=0.608
# Trying dst= 110, t1= 0.03, t2= 0.14 | acc= 0.663, acc_blur=0.598
# Trying dst= 110, t1= 0.03, t2= 0.15 | acc= 0.668, acc_blur=0.593
# Trying dst= 110, t1= 0.03, t2= 0.16 | acc= 0.668, acc_blur=0.588
# Trying dst= 110, t1= 0.03, t2= 0.17 | acc= 0.653, acc_blur=0.583
# Trying dst= 110, t1= 0.03, t2= 0.18 | acc= 0.638, acc_blur=0.573
# Trying dst= 110, t1= 0.03, t2= 0.19 | acc= 0.638, acc_blur=0.568
# Trying dst= 110, t1= 0.03, t2= 0.20 | acc= 0.628, acc_blur=0.563
# Trying dst= 110, t1= 0.03, t2= 0.21 | acc= 0.638, acc_blur=0.558
# Trying dst= 110, t1= 0.03, t2= 0.22 | acc= 0.633, acc_blur=0.558
# Trying dst= 110, t1= 0.03, t2= 0.23 | acc= 0.623, acc_blur=0.558
# Trying dst= 110, t1= 0.03, t2= 0.24 | acc= 0.608, acc_blur=0.558
# Trying dst= 110, t1= 0.03, t2= 0.25 | acc= 0.608, acc_blur=0.553
# Trying dst= 110, t1= 0.03, t2= 0.26 | acc= 0.608, acc_blur=0.553
# Trying dst= 110, t1= 0.03, t2= 0.27 | acc= 0.603, acc_blur=0.553
# Trying dst= 110, t1= 0.03, t2= 0.28 | acc= 0.593, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.29 | acc= 0.588, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.30 | acc= 0.588, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.31 | acc= 0.583, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.32 | acc= 0.583, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.33 | acc= 0.578, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.34 | acc= 0.578, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.35 | acc= 0.568, acc_blur=0.548
# Trying dst= 110, t1= 0.03, t2= 0.36 | acc= 0.568, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.37 | acc= 0.568, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.38 | acc= 0.568, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.39 | acc= 0.563, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.40 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.41 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.42 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.43 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.44 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.45 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.46 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.47 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.48 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.49 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.50 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.51 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.52 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.53 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.54 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.56 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.57 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.58 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.59 | acc= 0.558, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.60 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.61 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.62 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.63 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.64 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.65 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.66 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.67 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.68 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.69 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.70 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.71 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.72 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.73 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.74 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.75 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.76 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.77 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.78 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.79 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.80 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.81 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.82 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.83 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.84 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.85 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.86 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.87 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.88 | acc= 0.553, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.89 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.90 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.91 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.92 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.93 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.94 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.95 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.96 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.97 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.98 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 0.99 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.03, t2= 1.00 | acc= 0.548, acc_blur=0.543
# Trying dst= 110, t1= 0.04, t2= 0.09 | acc= 0.608, acc_blur=0.598
# Trying dst= 110, t1= 0.04, t2= 0.10 | acc= 0.638, acc_blur=0.598
# Trying dst= 110, t1= 0.04, t2= 0.11 | acc= 0.638, acc_blur=0.603
# Trying dst= 110, t1= 0.04, t2= 0.12 | acc= 0.658, acc_blur=0.603
# Trying dst= 110, t1= 0.04, t2= 0.13 | acc= 0.658, acc_blur=0.588
# Trying dst= 110, t1= 0.04, t2= 0.14 | acc= 0.663, acc_blur=0.578
# Trying dst= 110, t1= 0.04, t2= 0.15 | acc= 0.668, acc_blur=0.573
# Trying dst= 110, t1= 0.04, t2= 0.16 | acc= 0.668, acc_blur=0.568
# Trying dst= 110, t1= 0.04, t2= 0.17 | acc= 0.653, acc_blur=0.563
# Trying dst= 110, t1= 0.04, t2= 0.18 | acc= 0.638, acc_blur=0.553
# Trying dst= 110, t1= 0.04, t2= 0.19 | acc= 0.638, acc_blur=0.548
# Trying dst= 110, t1= 0.04, t2= 0.20 | acc= 0.628, acc_blur=0.543
# Trying dst= 110, t1= 0.04, t2= 0.21 | acc= 0.638, acc_blur=0.538
# Trying dst= 110, t1= 0.04, t2= 0.22 | acc= 0.633, acc_blur=0.538
# Trying dst= 110, t1= 0.04, t2= 0.23 | acc= 0.623, acc_blur=0.538
# Trying dst= 110, t1= 0.04, t2= 0.24 | acc= 0.608, acc_blur=0.538
# Trying dst= 110, t1= 0.04, t2= 0.25 | acc= 0.608, acc_blur=0.533
# Trying dst= 110, t1= 0.04, t2= 0.26 | acc= 0.608, acc_blur=0.533
# Trying dst= 110, t1= 0.04, t2= 0.27 | acc= 0.603, acc_blur=0.533
# Trying dst= 110, t1= 0.04, t2= 0.28 | acc= 0.593, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.29 | acc= 0.588, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.30 | acc= 0.588, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.31 | acc= 0.583, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.32 | acc= 0.583, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.33 | acc= 0.578, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.34 | acc= 0.578, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.35 | acc= 0.568, acc_blur=0.528
# Trying dst= 110, t1= 0.04, t2= 0.36 | acc= 0.568, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.37 | acc= 0.568, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.38 | acc= 0.568, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.39 | acc= 0.563, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.40 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.41 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.42 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.43 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.44 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.45 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.46 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.47 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.48 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.49 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.50 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.51 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.52 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.53 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.54 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.56 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.57 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.58 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.59 | acc= 0.558, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.60 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.61 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.62 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.63 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.64 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.65 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.66 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.67 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.68 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.69 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.70 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.71 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.72 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.73 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.74 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.75 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.76 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.77 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.78 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.79 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.80 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.81 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.82 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.83 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.84 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.85 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.86 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.87 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.88 | acc= 0.553, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.89 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.90 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.91 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.92 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.93 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.94 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.95 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.96 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.97 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.98 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 0.99 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.04, t2= 1.00 | acc= 0.548, acc_blur=0.523
# Trying dst= 110, t1= 0.05, t2= 0.09 | acc= 0.628, acc_blur=0.583
# Trying dst= 110, t1= 0.05, t2= 0.10 | acc= 0.658, acc_blur=0.583
# Trying dst= 110, t1= 0.05, t2= 0.11 | acc= 0.658, acc_blur=0.588
# Trying dst= 110, t1= 0.05, t2= 0.12 | acc= 0.678, acc_blur=0.588
# Trying dst= 110, t1= 0.05, t2= 0.13 | acc= 0.678, acc_blur=0.573
# Trying dst= 110, t1= 0.05, t2= 0.14 | acc= 0.683, acc_blur=0.563
# Trying dst= 110, t1= 0.05, t2= 0.15 | acc= 0.688, acc_blur=0.558
# Trying dst= 110, t1= 0.05, t2= 0.16 | acc= 0.688, acc_blur=0.553
# Trying dst= 110, t1= 0.05, t2= 0.17 | acc= 0.673, acc_blur=0.548
# Trying dst= 110, t1= 0.05, t2= 0.18 | acc= 0.658, acc_blur=0.538
# Trying dst= 110, t1= 0.05, t2= 0.19 | acc= 0.658, acc_blur=0.533
# Trying dst= 110, t1= 0.05, t2= 0.20 | acc= 0.648, acc_blur=0.528
# Trying dst= 110, t1= 0.05, t2= 0.21 | acc= 0.658, acc_blur=0.523
# Trying dst= 110, t1= 0.05, t2= 0.22 | acc= 0.653, acc_blur=0.523
# Trying dst= 110, t1= 0.05, t2= 0.23 | acc= 0.643, acc_blur=0.523
# Trying dst= 110, t1= 0.05, t2= 0.24 | acc= 0.628, acc_blur=0.523
# Trying dst= 110, t1= 0.05, t2= 0.25 | acc= 0.628, acc_blur=0.518
# Trying dst= 110, t1= 0.05, t2= 0.26 | acc= 0.628, acc_blur=0.518
# Trying dst= 110, t1= 0.05, t2= 0.27 | acc= 0.623, acc_blur=0.518
# Trying dst= 110, t1= 0.05, t2= 0.28 | acc= 0.613, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.29 | acc= 0.608, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.30 | acc= 0.608, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.31 | acc= 0.603, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.32 | acc= 0.603, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.33 | acc= 0.598, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.34 | acc= 0.598, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.35 | acc= 0.588, acc_blur=0.513
# Trying dst= 110, t1= 0.05, t2= 0.36 | acc= 0.588, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.37 | acc= 0.588, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.38 | acc= 0.588, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.39 | acc= 0.583, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.40 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.41 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.42 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.43 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.44 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.45 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.46 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.47 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.48 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.49 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.50 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.51 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.52 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.53 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.54 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.56 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.57 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.58 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.59 | acc= 0.578, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.60 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.61 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.62 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.63 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.64 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.65 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.66 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.67 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.68 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.69 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.70 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.71 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.72 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.73 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.74 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.75 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.76 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.77 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.78 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.79 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.80 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.81 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.82 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.83 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.84 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.85 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.86 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.87 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.88 | acc= 0.573, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.89 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.90 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.91 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.92 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.93 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.94 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.95 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.96 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.97 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.98 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 0.99 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.05, t2= 1.00 | acc= 0.568, acc_blur=0.508
# Trying dst= 110, t1= 0.06, t2= 0.09 | acc= 0.628, acc_blur=0.568
# Trying dst= 110, t1= 0.06, t2= 0.10 | acc= 0.658, acc_blur=0.568
# Trying dst= 110, t1= 0.06, t2= 0.11 | acc= 0.658, acc_blur=0.573
# Trying dst= 110, t1= 0.06, t2= 0.12 | acc= 0.678, acc_blur=0.573
# Trying dst= 110, t1= 0.06, t2= 0.13 | acc= 0.678, acc_blur=0.558
# Trying dst= 110, t1= 0.06, t2= 0.14 | acc= 0.683, acc_blur=0.548
# Trying dst= 110, t1= 0.06, t2= 0.15 | acc= 0.688, acc_blur=0.543
# Trying dst= 110, t1= 0.06, t2= 0.16 | acc= 0.688, acc_blur=0.538
# Trying dst= 110, t1= 0.06, t2= 0.17 | acc= 0.673, acc_blur=0.533
# Trying dst= 110, t1= 0.06, t2= 0.18 | acc= 0.658, acc_blur=0.523
# Trying dst= 110, t1= 0.06, t2= 0.19 | acc= 0.658, acc_blur=0.518
# Trying dst= 110, t1= 0.06, t2= 0.20 | acc= 0.648, acc_blur=0.513
# Trying dst= 110, t1= 0.06, t2= 0.21 | acc= 0.658, acc_blur=0.508
# Trying dst= 110, t1= 0.06, t2= 0.22 | acc= 0.653, acc_blur=0.508
# Trying dst= 110, t1= 0.06, t2= 0.23 | acc= 0.643, acc_blur=0.508
# Trying dst= 110, t1= 0.06, t2= 0.24 | acc= 0.628, acc_blur=0.508
# Trying dst= 110, t1= 0.06, t2= 0.25 | acc= 0.628, acc_blur=0.503
# Trying dst= 110, t1= 0.06, t2= 0.26 | acc= 0.628, acc_blur=0.503
# Trying dst= 110, t1= 0.06, t2= 0.27 | acc= 0.623, acc_blur=0.503
# Trying dst= 110, t1= 0.06, t2= 0.28 | acc= 0.613, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.29 | acc= 0.608, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.30 | acc= 0.608, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.31 | acc= 0.603, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.32 | acc= 0.603, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.33 | acc= 0.598, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.34 | acc= 0.598, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.35 | acc= 0.588, acc_blur=0.497
# Trying dst= 110, t1= 0.06, t2= 0.36 | acc= 0.588, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.37 | acc= 0.588, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.38 | acc= 0.588, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.39 | acc= 0.583, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.40 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.41 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.42 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.43 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.44 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.45 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.46 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.47 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.48 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.49 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.50 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.51 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.52 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.53 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.54 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.56 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.57 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.58 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.59 | acc= 0.578, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.60 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.61 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.62 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.63 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.64 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.65 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.66 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.67 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.68 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.69 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.70 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.71 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.72 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.73 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.74 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.75 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.76 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.77 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.78 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.79 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.80 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.81 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.82 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.83 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.84 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.85 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.86 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.87 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.88 | acc= 0.573, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.89 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.90 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.91 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.92 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.93 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.94 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.95 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.96 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.97 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.98 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 0.99 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.06, t2= 1.00 | acc= 0.568, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.09 | acc= 0.628, acc_blur=0.563
# Trying dst= 110, t1= 0.07, t2= 0.10 | acc= 0.658, acc_blur=0.563
# Trying dst= 110, t1= 0.07, t2= 0.11 | acc= 0.658, acc_blur=0.568
# Trying dst= 110, t1= 0.07, t2= 0.12 | acc= 0.678, acc_blur=0.568
# Trying dst= 110, t1= 0.07, t2= 0.13 | acc= 0.678, acc_blur=0.553
# Trying dst= 110, t1= 0.07, t2= 0.14 | acc= 0.683, acc_blur=0.543
# Trying dst= 110, t1= 0.07, t2= 0.15 | acc= 0.688, acc_blur=0.538
# Trying dst= 110, t1= 0.07, t2= 0.16 | acc= 0.688, acc_blur=0.533
# Trying dst= 110, t1= 0.07, t2= 0.17 | acc= 0.673, acc_blur=0.528
# Trying dst= 110, t1= 0.07, t2= 0.18 | acc= 0.658, acc_blur=0.518
# Trying dst= 110, t1= 0.07, t2= 0.19 | acc= 0.658, acc_blur=0.513
# Trying dst= 110, t1= 0.07, t2= 0.20 | acc= 0.648, acc_blur=0.508
# Trying dst= 110, t1= 0.07, t2= 0.21 | acc= 0.658, acc_blur=0.503
# Trying dst= 110, t1= 0.07, t2= 0.22 | acc= 0.653, acc_blur=0.503
# Trying dst= 110, t1= 0.07, t2= 0.23 | acc= 0.643, acc_blur=0.503
# Trying dst= 110, t1= 0.07, t2= 0.24 | acc= 0.628, acc_blur=0.503
# Trying dst= 110, t1= 0.07, t2= 0.25 | acc= 0.628, acc_blur=0.497
# Trying dst= 110, t1= 0.07, t2= 0.26 | acc= 0.628, acc_blur=0.497
# Trying dst= 110, t1= 0.07, t2= 0.27 | acc= 0.623, acc_blur=0.497
# Trying dst= 110, t1= 0.07, t2= 0.28 | acc= 0.613, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.29 | acc= 0.608, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.30 | acc= 0.608, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.31 | acc= 0.603, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.32 | acc= 0.603, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.33 | acc= 0.598, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.34 | acc= 0.598, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.35 | acc= 0.588, acc_blur=0.492
# Trying dst= 110, t1= 0.07, t2= 0.36 | acc= 0.588, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.37 | acc= 0.588, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.38 | acc= 0.588, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.39 | acc= 0.583, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.40 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.41 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.42 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.43 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.44 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.45 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.46 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.47 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.48 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.49 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.50 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.51 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.52 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.53 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.54 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.56 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.57 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.58 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.59 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.60 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.61 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.62 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.63 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.64 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.65 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.66 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.67 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.68 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.69 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.70 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.71 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.72 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.73 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.74 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.75 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.76 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.77 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.78 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.79 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.80 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.81 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.82 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.83 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.84 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.85 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.86 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.87 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.88 | acc= 0.573, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.89 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.90 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.91 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.92 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.93 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.94 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.95 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.96 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.97 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.98 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 0.99 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.07, t2= 1.00 | acc= 0.568, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.09 | acc= 0.618, acc_blur=0.558
# Trying dst= 110, t1= 0.08, t2= 0.10 | acc= 0.648, acc_blur=0.563
# Trying dst= 110, t1= 0.08, t2= 0.11 | acc= 0.648, acc_blur=0.563
# Trying dst= 110, t1= 0.08, t2= 0.12 | acc= 0.673, acc_blur=0.563
# Trying dst= 110, t1= 0.08, t2= 0.13 | acc= 0.668, acc_blur=0.553
# Trying dst= 110, t1= 0.08, t2= 0.14 | acc= 0.673, acc_blur=0.538
# Trying dst= 110, t1= 0.08, t2= 0.15 | acc= 0.678, acc_blur=0.533
# Trying dst= 110, t1= 0.08, t2= 0.16 | acc= 0.678, acc_blur=0.523
# Trying dst= 110, t1= 0.08, t2= 0.17 | acc= 0.663, acc_blur=0.523
# Trying dst= 110, t1= 0.08, t2= 0.18 | acc= 0.648, acc_blur=0.513
# Trying dst= 110, t1= 0.08, t2= 0.19 | acc= 0.648, acc_blur=0.503
# Trying dst= 110, t1= 0.08, t2= 0.20 | acc= 0.638, acc_blur=0.503
# Trying dst= 110, t1= 0.08, t2= 0.21 | acc= 0.643, acc_blur=0.497
# Trying dst= 110, t1= 0.08, t2= 0.22 | acc= 0.648, acc_blur=0.497
# Trying dst= 110, t1= 0.08, t2= 0.23 | acc= 0.628, acc_blur=0.497
# Trying dst= 110, t1= 0.08, t2= 0.24 | acc= 0.618, acc_blur=0.497
# Trying dst= 110, t1= 0.08, t2= 0.25 | acc= 0.618, acc_blur=0.492
# Trying dst= 110, t1= 0.08, t2= 0.26 | acc= 0.618, acc_blur=0.492
# Trying dst= 110, t1= 0.08, t2= 0.27 | acc= 0.613, acc_blur=0.492
# Trying dst= 110, t1= 0.08, t2= 0.28 | acc= 0.603, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.29 | acc= 0.598, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.30 | acc= 0.598, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.31 | acc= 0.593, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.32 | acc= 0.588, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.33 | acc= 0.588, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.34 | acc= 0.588, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.35 | acc= 0.578, acc_blur=0.487
# Trying dst= 110, t1= 0.08, t2= 0.36 | acc= 0.578, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.37 | acc= 0.578, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.38 | acc= 0.578, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.39 | acc= 0.573, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.40 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.41 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.42 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.43 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.44 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.45 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.46 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.48 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.49 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.50 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.51 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.52 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.53 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.54 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.55 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.56 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.57 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.58 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.59 | acc= 0.568, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.60 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.61 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.62 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.63 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.64 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.65 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.66 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.67 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.68 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.69 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.70 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.71 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.72 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.73 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.74 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.75 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.76 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.77 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.78 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.79 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.80 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.81 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.82 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.83 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.84 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.85 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.86 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.87 | acc= 0.563, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.88 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.89 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.90 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.91 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.92 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.93 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.94 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.95 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.96 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.97 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.98 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 0.99 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.08, t2= 1.00 | acc= 0.558, acc_blur=0.482
# Trying dst= 110, t1= 0.09, t2= 0.10 | acc= 0.648, acc_blur=0.553
# Trying dst= 110, t1= 0.09, t2= 0.11 | acc= 0.648, acc_blur=0.553
# Trying dst= 110, t1= 0.09, t2= 0.12 | acc= 0.673, acc_blur=0.553
# Trying dst= 110, t1= 0.09, t2= 0.13 | acc= 0.668, acc_blur=0.543
# Trying dst= 110, t1= 0.09, t2= 0.14 | acc= 0.673, acc_blur=0.528
# Trying dst= 110, t1= 0.09, t2= 0.15 | acc= 0.678, acc_blur=0.523
# Trying dst= 110, t1= 0.09, t2= 0.16 | acc= 0.678, acc_blur=0.513
# Trying dst= 110, t1= 0.09, t2= 0.17 | acc= 0.663, acc_blur=0.513
# Trying dst= 110, t1= 0.09, t2= 0.18 | acc= 0.648, acc_blur=0.503
# Trying dst= 110, t1= 0.09, t2= 0.19 | acc= 0.648, acc_blur=0.492
# ...
# Trying dst= 120, t1= 0.01, t2= 0.22 | acc= 0.648, acc_blur=0.693
# Trying dst= 120, t1= 0.01, t2= 0.23 | acc= 0.648, acc_blur=0.693
# Trying dst= 120, t1= 0.01, t2= 0.24 | acc= 0.648, acc_blur=0.688
# Trying dst= 120, t1= 0.01, t2= 0.25 | acc= 0.648, acc_blur=0.678
# Trying dst= 120, t1= 0.01, t2= 0.26 | acc= 0.653, acc_blur=0.678
# Trying dst= 120, t1= 0.01, t2= 0.27 | acc= 0.643, acc_blur=0.678
# Trying dst= 120, t1= 0.01, t2= 0.28 | acc= 0.623, acc_blur=0.678
# Trying dst= 120, t1= 0.01, t2= 0.29 | acc= 0.613, acc_blur=0.673
# Trying dst= 120, t1= 0.01, t2= 0.30 | acc= 0.613, acc_blur=0.668
# Trying dst= 120, t1= 0.01, t2= 0.31 | acc= 0.603, acc_blur=0.668
# Trying dst= 120, t1= 0.01, t2= 0.32 | acc= 0.603, acc_blur=0.668
# Trying dst= 120, t1= 0.01, t2= 0.33 | acc= 0.598, acc_blur=0.668
# Trying dst= 120, t1= 0.01, t2= 0.34 | acc= 0.598, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.35 | acc= 0.588, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.36 | acc= 0.588, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.37 | acc= 0.583, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.38 | acc= 0.583, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.39 | acc= 0.578, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.40 | acc= 0.578, acc_blur=0.663
# Trying dst= 120, t1= 0.01, t2= 0.41 | acc= 0.578, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.42 | acc= 0.573, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.43 | acc= 0.568, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.44 | acc= 0.568, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.45 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.46 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.47 | acc= 0.558, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.48 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.49 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.50 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.51 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.52 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.53 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.54 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.56 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.57 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.58 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.59 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.60 | acc= 0.563, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.61 | acc= 0.558, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.62 | acc= 0.558, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.63 | acc= 0.558, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.64 | acc= 0.558, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.65 | acc= 0.558, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.66 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.67 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.68 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.69 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.70 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.71 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.72 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.73 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.74 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.75 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.76 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.77 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.78 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.79 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.80 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.81 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.82 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.83 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.84 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.85 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.86 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.87 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.88 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.89 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.90 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.91 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.92 | acc= 0.553, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.93 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.94 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.95 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.96 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.97 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.98 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 0.99 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.01, t2= 1.00 | acc= 0.548, acc_blur=0.658
# Trying dst= 120, t1= 0.02, t2= 0.09 | acc= 0.643, acc_blur=0.693
# Trying dst= 120, t1= 0.02, t2= 0.10 | acc= 0.648, acc_blur=0.693
# Trying dst= 120, t1= 0.02, t2= 0.11 | acc= 0.673, acc_blur=0.698
# Trying dst= 120, t1= 0.02, t2= 0.12 | acc= 0.668, acc_blur=0.698
# Trying dst= 120, t1= 0.02, t2= 0.13 | acc= 0.683, acc_blur=0.698
# Trying dst= 120, t1= 0.02, t2= 0.14 | acc= 0.683, acc_blur=0.693
# Trying dst= 120, t1= 0.02, t2= 0.15 | acc= 0.693, acc_blur=0.683
# Trying dst= 120, t1= 0.02, t2= 0.16 | acc= 0.698, acc_blur=0.678
# Trying dst= 120, t1= 0.02, t2= 0.17 | acc= 0.698, acc_blur=0.678
# Trying dst= 120, t1= 0.02, t2= 0.18 | acc= 0.709, acc_blur=0.668
# Trying dst= 120, t1= 0.02, t2= 0.19 | acc= 0.704, acc_blur=0.658
# Trying dst= 120, t1= 0.02, t2= 0.20 | acc= 0.698, acc_blur=0.658
# Trying dst= 120, t1= 0.02, t2= 0.21 | acc= 0.683, acc_blur=0.648
# Trying dst= 120, t1= 0.02, t2= 0.22 | acc= 0.683, acc_blur=0.648
# Trying dst= 120, t1= 0.02, t2= 0.23 | acc= 0.683, acc_blur=0.648
# Trying dst= 120, t1= 0.02, t2= 0.24 | acc= 0.683, acc_blur=0.643
# Trying dst= 120, t1= 0.02, t2= 0.25 | acc= 0.683, acc_blur=0.633
# Trying dst= 120, t1= 0.02, t2= 0.26 | acc= 0.688, acc_blur=0.633
# Trying dst= 120, t1= 0.02, t2= 0.27 | acc= 0.678, acc_blur=0.633
# Trying dst= 120, t1= 0.02, t2= 0.28 | acc= 0.658, acc_blur=0.633
# Trying dst= 120, t1= 0.02, t2= 0.29 | acc= 0.648, acc_blur=0.628
# Trying dst= 120, t1= 0.02, t2= 0.30 | acc= 0.648, acc_blur=0.623
# Trying dst= 120, t1= 0.02, t2= 0.31 | acc= 0.638, acc_blur=0.623
# Trying dst= 120, t1= 0.02, t2= 0.32 | acc= 0.638, acc_blur=0.623
# Trying dst= 120, t1= 0.02, t2= 0.33 | acc= 0.633, acc_blur=0.623
# Trying dst= 120, t1= 0.02, t2= 0.34 | acc= 0.633, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.35 | acc= 0.623, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.36 | acc= 0.623, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.37 | acc= 0.618, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.38 | acc= 0.618, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.39 | acc= 0.613, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.40 | acc= 0.613, acc_blur=0.618
# Trying dst= 120, t1= 0.02, t2= 0.41 | acc= 0.613, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.42 | acc= 0.608, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.43 | acc= 0.603, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.44 | acc= 0.603, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.45 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.46 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.47 | acc= 0.593, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.48 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.49 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.50 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.51 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.52 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.53 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.54 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.56 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.57 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.58 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.59 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.60 | acc= 0.598, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.61 | acc= 0.593, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.62 | acc= 0.593, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.63 | acc= 0.593, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.64 | acc= 0.593, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.65 | acc= 0.593, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.66 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.67 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.68 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.69 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.70 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.71 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.72 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.73 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.74 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.75 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.76 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.77 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.78 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.79 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.80 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.81 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.82 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.83 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.84 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.85 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.86 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.87 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.88 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.89 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.90 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.91 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.92 | acc= 0.588, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.93 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.94 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.95 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.96 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.97 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.98 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 0.99 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.02, t2= 1.00 | acc= 0.583, acc_blur=0.613
# Trying dst= 120, t1= 0.03, t2= 0.09 | acc= 0.633, acc_blur=0.643
# Trying dst= 120, t1= 0.03, t2= 0.10 | acc= 0.638, acc_blur=0.643
# Trying dst= 120, t1= 0.03, t2= 0.11 | acc= 0.663, acc_blur=0.648
# Trying dst= 120, t1= 0.03, t2= 0.12 | acc= 0.658, acc_blur=0.648
# Trying dst= 120, t1= 0.03, t2= 0.13 | acc= 0.673, acc_blur=0.648
# Trying dst= 120, t1= 0.03, t2= 0.14 | acc= 0.673, acc_blur=0.643
# Trying dst= 120, t1= 0.03, t2= 0.15 | acc= 0.683, acc_blur=0.633
# Trying dst= 120, t1= 0.03, t2= 0.16 | acc= 0.688, acc_blur=0.628
# Trying dst= 120, t1= 0.03, t2= 0.17 | acc= 0.688, acc_blur=0.628
# Trying dst= 120, t1= 0.03, t2= 0.18 | acc= 0.698, acc_blur=0.618
# Trying dst= 120, t1= 0.03, t2= 0.19 | acc= 0.693, acc_blur=0.608
# Trying dst= 120, t1= 0.03, t2= 0.20 | acc= 0.688, acc_blur=0.608
# Trying dst= 120, t1= 0.03, t2= 0.21 | acc= 0.673, acc_blur=0.598
# Trying dst= 120, t1= 0.03, t2= 0.22 | acc= 0.673, acc_blur=0.598
# Trying dst= 120, t1= 0.03, t2= 0.23 | acc= 0.673, acc_blur=0.598
# Trying dst= 120, t1= 0.03, t2= 0.24 | acc= 0.673, acc_blur=0.593
# Trying dst= 120, t1= 0.03, t2= 0.25 | acc= 0.673, acc_blur=0.583
# Trying dst= 120, t1= 0.03, t2= 0.26 | acc= 0.678, acc_blur=0.583
# Trying dst= 120, t1= 0.03, t2= 0.27 | acc= 0.668, acc_blur=0.583
# Trying dst= 120, t1= 0.03, t2= 0.28 | acc= 0.648, acc_blur=0.583
# Trying dst= 120, t1= 0.03, t2= 0.29 | acc= 0.638, acc_blur=0.578
# Trying dst= 120, t1= 0.03, t2= 0.30 | acc= 0.638, acc_blur=0.573
# Trying dst= 120, t1= 0.03, t2= 0.31 | acc= 0.628, acc_blur=0.573
# Trying dst= 120, t1= 0.03, t2= 0.32 | acc= 0.628, acc_blur=0.573
# Trying dst= 120, t1= 0.03, t2= 0.33 | acc= 0.623, acc_blur=0.573
# Trying dst= 120, t1= 0.03, t2= 0.34 | acc= 0.623, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.35 | acc= 0.613, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.36 | acc= 0.613, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.37 | acc= 0.608, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.38 | acc= 0.608, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.39 | acc= 0.603, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.40 | acc= 0.603, acc_blur=0.568
# Trying dst= 120, t1= 0.03, t2= 0.41 | acc= 0.603, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.42 | acc= 0.598, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.43 | acc= 0.593, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.44 | acc= 0.593, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.45 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.46 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.47 | acc= 0.583, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.48 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.49 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.50 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.51 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.52 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.53 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.54 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.56 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.57 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.58 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.59 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.60 | acc= 0.588, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.61 | acc= 0.583, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.62 | acc= 0.583, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.63 | acc= 0.583, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.64 | acc= 0.583, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.65 | acc= 0.583, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.66 | acc= 0.578, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.67 | acc= 0.578, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.68 | acc= 0.578, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.69 | acc= 0.578, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.70 | acc= 0.578, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.71 | acc= 0.578, acc_blur=0.563
# Trying dst= 120, t1= 0.03, t2= 0.72 | acc= 0.578, acc_blur=0.563
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 51
#      49 # compute label with and without blur
#      50 _, label, _ = rate_hair(img_rgb, t1= t1, t2= t2, dst= p, blur= False)
# ---> 51 _, label_blur, _ = rate_hair(img_rgb, t1= t1, t2= t2, dst= p)
#      52 pred_labels.append(label)
#      53 pred_labels_blur.append(label_blur)
#
# File c:\Users\piras\Desktop\Uni\Lectures and Exercises S2\Projects in DS\2025-FYP-Final-GroupE\util\img_util.py:97, in rate_hair(image, dst, t1, t2, blur)
#      92 Mask = Mask.astype(float)
#      94 # --------------------------------------------------------
#      95
#      96 # if no non-zero pixels are found, the mask is reset
# ---> 97 i, j = np.where( Mask != 0 )
#      99 if i.size == 0:
#     100     Mask = np.zeros(image_size)
#
# KeyboardInterrupt:
